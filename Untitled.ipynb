# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %%
soup = BeautifulSoup('https://drees.shinyapps.io/demographie-ps/')
# Out:
# C:\Users\jb\conda\lib\site-packages\bs4\__init__.py:404: MarkupResemblesLocatorWarning: The input looks more like a URL than markup. You may want to use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(

# %%
print(soup.prettify())
# Out:
# <html>
#  <body>
#   <p>
#    https://drees.shinyapps.io/demographie-ps/
#   </p>
#  </body>
# </html>

# %%
https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %%
url = 'https://drees.shinyapps.io/demographie-ps/'
response = requests.get(url)
soup = BeautifulSoup(response.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <base href="_w_518d6870/"/>
# <script type="text/javascript">
# (function() {
#   var workerId = '_w_518d6870';
#   // remove base href if worker ID is in url
#   if (window.location.href.indexOf(workerId) > 0) {
#     document.querySelector('base').removeAttribute('href');
#   }
# })();
# </script>
# <script type="text/javascript">
#       var __connect = {
#         shinyPre101: false
#       }
#       </script>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <script type="application/shiny-singletons"></script>
# <script type="application/html-dependencies">jquery[3.6.0];shiny-css[1.7.1];shiny-javascript[1.7.1];selectize[0.12.4];font-awesome[5.15.3];ionrangeslider-javascript[2.3.1];strftime[0.9.2];ionrangeslider-css[2.3.1];shinyBS[0.61.1];htmlwidgets[1.5.4];datatables-css[0.0.0];datatables-binding[0.23];crosstalk[1.2.0];bootstrap[3.4.1]</script>
# <script src="shared/jquery.min.js"></script>
# ...

# %%
# Find select tag
select_tag = soup.find("select")

# find all option tag inside select tag
options = select_tag.find_all("option")

# Iterate through all option tags and get inside text
for option in options:
    print(option.text)
# Out:
# Audioprothésistes
# Dentistes
# Diététiciens
# Ergothérapeutes
# Infirmiers
# Manipulateurs ERM
# Masseurs-kinésithérapeutes
# Médecins
# Opticiens-lunetiers
# Orthophonistes
# Orthoptistes
# Pédicures-podologues
# Pharmaciens
# Professionnels de l'appareillage
# Psychologues
# Psychomotriciens
# Sages-femmes
# Techniciens de laboratoire

# %%
pip install selenium
# Out:
# ...
#      ---------------------------------------- 6.3/6.3 MB 17.5 MB/s eta 0:00:00
# ...
#      ------------------------------------- 384.9/384.9 kB 12.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 58.3/58.3 kB ? eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from selenium.webdriver.support.ui import Select

# %%
driver = webdriver.Chrome()
driver.get(url)


#select = Select(driver.find_element_by_id('VarL'))

# identify dropdown with Select class
driver.implicitly_wait(1)


driver.find_element("xpath","//div[@class='selectize-input items not-full has-options has-items']").click();
driver.find_element("xpath","//*[contains(text(),'Département')]").click();

#sel = Select(driver.find_element("xpath","//select[@id='VarL']"))
#sel.select_by_visible_text("Département")



#select by visible text
#select.select_by_visible_text('Département')

# %%
from selenium import webdriver
from selenium.webdriver.support.select import Select

driver = webdriver.Chrome()

driver.implicitly_wait(0.5)
driver.get("https://www.tutorialspoint.com/selenium/selenium_automation_practice.htm")
# identify dropdown with Select class
sel = Select(driver.find_element_by_xpath("//select[@name='continents']"))
#select by select_by_visible_text() method
sel.select_by_visible_text("Europe")
time.sleep(0.8)
#select by select_by_index() method
sel.select_by_index(0)
driver.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5040\2430536881.py in <module>
#       7 driver.get("https://www.tutorialspoint.com/selenium/selenium_automation_practice.htm")
#       8 # identify dropdown with Select class
# ----> 9 sel = Select(driver.find_element_by_xpath("//select[@name='continents']"))
#      10 #select by select_by_visible_text() method
#      11 sel.select_by_visible_text("Europe")
#
# AttributeError: 'WebDriver' object has no attribute 'find_element_by_xpath'
