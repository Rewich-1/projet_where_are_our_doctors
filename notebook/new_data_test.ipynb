# %%
import pandas as pd
#import geoviews as gv
#import geoviews.feature as gf
#import xarray as xr
#from cartopy import crs
import geopandas as gpd
import json
import folium # map rendering library
#import streamlit as st #creating an app
#from streamlit_folium import folium_static 
import numpy as np

# %%
df = pd.read_csv("PS_LibreAcces_Personne_activite_202212080954.txt", sep="|")
# Out:
# C:\Users\jb\AppData\Local\Temp\ipykernel_13748\608093414.py:1: DtypeWarning: Columns (28,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("PS_LibreAcces_Personne_activite_202212080954.txt", sep="|")

# %%
df.drop_duplicates(subset=["Nom d'exercice","Prénom d'exercice"])
# Out:
#          Type d'identifiant PP Identifiant PP Identification nationale PP  \
# 0                            0      010000057                  0010000057
# 1                            0      010000123                  0010000123
# 2                            0      010000479                  0010000479
# 3                            0      010004729                  0010004729
# 4                            0      010004992                  0010004992
# ...                        ...            ...                         ...
# 1860857                      8    10108464933                810108464933
# 1860858                      8    10108466961                810108466961
# 1860859                      8    10108475558                810108475558
# 1860860                      8    10108476580                810108476580
# 1860861                      8    10108480681                810108480681
#
#         Code civilité d'exercice Libellé civilité d'exercice Code civilité  \
# ...

# %%
df.columns
# Out:
# Index(['Type d'identifiant PP', 'Identifiant PP',
#        'Identification nationale PP', 'Code civilité d'exercice',
#        'Libellé civilité d'exercice', 'Code civilité', 'Libellé civilité',
#        'Nom d'exercice', 'Prénom d'exercice', 'Code profession',
#        'Libellé profession', 'Code catégorie professionnelle',
#        'Libellé catégorie professionnelle', 'Code type savoir-faire',
#        'Libellé type savoir-faire', 'Code savoir-faire',
#        'Libellé savoir-faire', 'Code mode exercice', 'Libellé mode exercice',
#        'Numéro SIRET site', 'Numéro SIREN site', 'Numéro FINESS site',
#        'Numéro FINESS établissement juridique',
#        'Identifiant technique de la structure', 'Raison sociale site',
#        'Enseigne commerciale site',
#        'Complément destinataire (coord. structure)',
#        'Complément point géographique (coord. structure)',
#        'Numéro Voie (coord. structure)',
#        'Indice répétition voie (coord. structure)',
# ...

# %%
df
# Out:
#          Type d'identifiant PP Identifiant PP Identification nationale PP  \
# 0                            0      010000057                  0010000057
# 1                            0      010000123                  0010000123
# 2                            0      010000479                  0010000479
# 3                            0      010004729                  0010004729
# 4                            0      010004992                  0010004992
# ...                        ...            ...                         ...
# 1860857                      8    10108464933                810108464933
# 1860858                      8    10108466961                810108466961
# 1860859                      8    10108475558                810108475558
# 1860860                      8    10108476580                810108476580
# 1860861                      8    10108480681                810108480681
#
#         Code civilité d'exercice Libellé civilité d'exercice Code civilité  \
# ...

# %%
df.drop_duplicates(subset=["Libellé profession"])["Libellé profession"]
# Out:
# 0                             Ostéopathe
# 5                      Opticien-Lunetier
# 7                     Assistant dentaire
# 8              Technicien de Laboratoire
# 9                            Psychologue
# 12                      Psychothérapeute
# 14                        Ergothérapeute
# 15                           Diététicien
# 17                      Manipulateur ERM
# 19                      Assistant social
# 34                     Audio-Prothésiste
# 45                       Psychomotricien
# 68                         Orthophoniste
# 118                          Orthoptiste
# 156                     Orthoprothésiste
# 281              Orthopédiste-Orthésiste
# 444                      Podo-Orthésiste
# 866                        Chiropracteur
# 2049                          Pharmacien
# 2052                             Médecin
# 2053                          Sage-Femme
# 2062                 Chirurgien-Dentiste
# 3516            Masseur-Kinésithérapeute
# ...

# %%
df.drop_duplicates(subset=["Libellé savoir-faire"])["Libellé savoir-faire"]
# Out:
# 0                                                       NaN
# 2052                       Spécialiste en Médecine Générale
# 2055                                       Radio-diagnostic
# 2056                      Gastro-entérologie et hépatologie
# 2058                                   Chirurgie urologique
#                                 ...
# 192599           Biologie médicale option biologie générale
# 228828           Biologie médicale option agents infectieux
# 287271             Chirurgie maxillo-faciale (réforme 2017)
# 482613    Biologie médicale option hématologie et immuno...
# 846917    Chirurgie pédiatrique option orthopédie pédiat...
# Name: Libellé savoir-faire, Length: 83, dtype: object

# %%
df2 = df[df["Libellé profession"] == "Médecin"]

# %%
df2.drop_duplicates(subset=["Nom d'exercice","Prénom d'exercice"])
# Out:
#          Type d'identifiant PP Identifiant PP Identification nationale PP  \
# 2052                         8    10000013028                810000013028
# 2055                         8    10000023373                810000023373
# 2056                         8    10000025832                810000025832
# 2058                         8    10000033984                810000033984
# 2060                         8    10000038983                810000038983
# ...                        ...            ...                         ...
# 1860774                      8    10108217554                810108217554
# 1860775                      8    10108219360                810108219360
# 1860776                      8    10108229120                810108229120
# 1860801                      8    10108297663                810108297663
# 1860812                      8    10108329904                810108329904
#
#         Code civilité d'exercice Libellé civilité d'exercice Code civilité  \
# ...

# %%
df3 = pd.read_csv("PS_LibreAcces_Personne_activite_202212080954.txt", sep="|")
# Out:
# C:\Users\jb\AppData\Local\Temp\ipykernel_13748\3187323798.py:1: DtypeWarning: Columns (28,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   df3 = pd.read_csv("PS_LibreAcces_Personne_activite_202212080954.txt", sep="|")

# %%
df3.columns
# Out:
# Index(['Type d'identifiant PP', 'Identifiant PP',
#        'Identification nationale PP', 'Code civilité d'exercice',
#        'Libellé civilité d'exercice', 'Code civilité', 'Libellé civilité',
#        'Nom d'exercice', 'Prénom d'exercice', 'Code profession',
#        'Libellé profession', 'Code catégorie professionnelle',
#        'Libellé catégorie professionnelle', 'Code type savoir-faire',
#        'Libellé type savoir-faire', 'Code savoir-faire',
#        'Libellé savoir-faire', 'Code mode exercice', 'Libellé mode exercice',
#        'Numéro SIRET site', 'Numéro SIREN site', 'Numéro FINESS site',
#        'Numéro FINESS établissement juridique',
#        'Identifiant technique de la structure', 'Raison sociale site',
#        'Enseigne commerciale site',
#        'Complément destinataire (coord. structure)',
#        'Complément point géographique (coord. structure)',
#        'Numéro Voie (coord. structure)',
#        'Indice répétition voie (coord. structure)',
# ...

# %%
df3
# Out:
#          Type d'identifiant PP Identifiant PP Identification nationale PP  \
# 0                            0      010000057                  0010000057
# 1                            0      010000123                  0010000123
# 2                            0      010000479                  0010000479
# 3                            0      010004729                  0010004729
# 4                            0      010004992                  0010004992
# ...                        ...            ...                         ...
# 1860857                      8    10108464933                810108464933
# 1860858                      8    10108466961                810108466961
# 1860859                      8    10108475558                810108475558
# 1860860                      8    10108476580                810108476580
# 1860861                      8    10108480681                810108480681
#
#         Code civilité d'exercice Libellé civilité d'exercice Code civilité  \
# ...

# %%
df5 = df3.groupby("Libellé Département (structure)")["Libellé Département (structure)"].count().reset_index(name="count")

# %%
df5
# Out:
# Empty DataFrame
# Columns: [Libellé Département (structure), count]
# Index: []

# %%
df4 = df3.groupby("Libellé profession")["Libellé profession"].count().reset_index(name="count")

# %%
df4
# Out:
#                  Libellé profession   count
# 0   Acteur caractérisé par son rôle     203
# 1                Assistant dentaire   17374
# 2                  Assistant social   49045
# 3                 Audio-Prothésiste    8371
# 4                     Chiropracteur    1902
# 5               Chirurgien-Dentiste   66923
# 6                       Diététicien   24836
# 7                       Epithésiste     103
# 8                    Ergothérapeute   19686
# 9                         Infirmier  525334
# 10                 Manipulateur ERM   43037
# 11         Masseur-Kinésithérapeute  124006
# 12                          Médecin  486449
# 13                       Oculariste      76
# 14                Opticien-Lunetier   57170
# 15                    Orthophoniste   32157
# 16                 Orthoprothésiste    1909
# 17                      Orthoptiste    8150
# 18          Orthopédiste-Orthésiste    2846
# 19                       Ostéopathe   39489
# ...

# %%
df5 = df3.groupby("Libellé savoir-faire")["Libellé savoir-faire"].count().reset_index(name="count")

# %%
df5
# Out:
#                           Libellé savoir-faire  count
# 0                                 Allergologie    529
# 1          Anatomie et cytologie pathologiques   4985
# 2                       Anesthesie-réanimation  21036
# 3                            Biologie médicale   4236
# 4   Biologie médicale option agents infectieux      5
# ..                                         ...    ...
# 77                                Rhumatologie   4896
# 78          Santé publique et médecine sociale   2666
# 79            Spécialiste en Médecine Générale  96911
# 80                                Stomatologie   1421
# 81                                    Urologie     31
#
# [82 rows x 2 columns]
